# %% [markdown]
# # OOP Open-Book Practice Quiz
# ## 1. Basic Concepts

# %% [markdown]
# 1. What is a **class** in OOP?
# **Answer:**

# %% [markdown]
# 2. What is an **object**?
# **Answer:**

# %% [markdown]
# 3. Name **three key features of OOP**.
# **Answer:**

# %% [markdown]
# 4. What is **inheritance** in OOP? Give a small example.
# **Answer:**

# %% [markdown]
# 5. What is **polymorphism**? Give an example scenario.
# **Answer:**

# %% [markdown]
# ## 2. Coding & Syntax

# %%
# 6. Write a simple Python class called Dog with an attribute 'name' and a method 'bark()'
# that prints 'Woof!'
# Answer:

# %%
# 7. Create an object 'my_dog' of class Dog and call its bark() method
# Answer:

# %%
# 8. Define a constructor in Python with a short example
# Answer:

# %%
# 9. Write a class Rectangle with attributes length and width and a method area()
# that returns the area
# Answer:

# %%
# 10. Create an instance of Rectangle with length=5 and width=3 and print its area
# Answer:

# %% [markdown]
# ## 3. Advanced Concepts

# %% [markdown]
# 11. What is **encapsulation** in OOP?
# **Answer:**

# %% [markdown]
# 12. Explain **method overriding** with a short example.
# **Answer:**

# %% [markdown]
# 13. What is a **class variable** vs an **instance variable**?
# **Answer:**

# %% [markdown]
# 14. Give an example of **polymorphism in Python**.
# **Answer:**

# %% [markdown]
# 15. List **advantages of OOP** over procedural programming.
# **Answer:**
